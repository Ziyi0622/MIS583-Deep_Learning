# %% [markdown]
# # Assignment 3: Self-supervised and transfer learning on CIFAR10

# %% [markdown]
# Before we start, please put your name and SID in following format: <br>
# : LASTNAME Firstname, ?00000000   //   e.g.) 李晨愷 M114020035

# %% [markdown]
# **Your Answer:**
# Hi I'm 莊子儀, B104020006.

# %% [markdown]
# ## Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Setup (5 points)
#
# The first thing to do is implement a dataset class to load rotated CIFAR10 images with matching labels. Since there is already a CIFAR10 dataset class implemented in `torchvision`, we will extend this class and modify the `__get_item__` method appropriately to load rotated images.
#
# Each rotation label should be an integer in the set {0, 1, 2, 3} which correspond to rotations of 0, 90, 180, or 270 degrees respectively.

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import random


def rotate_img(img, rot):
    if rot == 0: # 0 degrees rotation
        return img
    #######################################################################
    #        TODO: Implement rotate_img() - return the rotated img        #
    #######################################################################
    elif rot == 1:  # 90 degrees rotation
        return transforms.functional.rotate(img, 90)
    elif rot == 2:  # 180 degrees rotation
        return transforms.functional.rotate(img, 180)
    elif rot == 3:  # 270 degrees rotation
        return transforms.functional.rotate(img, 270)
    else:
        raise ValueError('rotation should be 0, 90, 180, or 270 degrees')

    #######################################################################
    #                           End of your code                          #
    #######################################################################

class CIFAR10Rotation(torchvision.datasets.CIFAR10):

    def __init__(self, root, train, download, transform) -> None:
        super().__init__(root=root, train=train, download=download, transform=transform)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index: int):
        image, cls_label = super().__getitem__(index)

        # randomly select image rotation
        rotation_label = random.choice([0, 1, 2, 3])
        image_rotated = rotate_img(image, rotation_label)

        rotation_label = torch.tensor(rotation_label).long()
        return image, image_rotated, rotation_label, torch.tensor(cls_label).long()

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

batch_size = 128

trainset = CIFAR10Rotation(root='./data', train=True,
                                        download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = CIFAR10Rotation(root='./data', train=False,
                                       download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:16<00:00, 10.2MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# Show some example images and rotated images with labels:

# %%
import matplotlib.pyplot as plt

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

rot_classes = ('0', '90', '180', '270')


def imshow(img):
    # unnormalize
    img = transforms.Normalize((0, 0, 0), (1/0.2023, 1/0.1994, 1/0.2010))(img)
    img = transforms.Normalize((-0.4914, -0.4822, -0.4465), (1, 1, 1))(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


dataiter = iter(trainloader)
images, rot_images, rot_labels, labels = next(dataiter)

# print images and rotated images
img_grid = imshow(torchvision.utils.make_grid(images[:4], padding=0))
print('Class labels: ', ' '.join(f'{classes[labels[j]]:5s}' for j in range(4)))
img_grid = imshow(torchvision.utils.make_grid(rot_images[:4], padding=0))
print('Rotation labels: ', ' '.join(f'{rot_classes[rot_labels[j]]:5s}' for j in range(4)))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Class labels:  plane car   plane ship
# Rotation labels:  0     180   90    90

# %% [markdown]
# # Evaluation code

# %%
import time

def run_test(net, testloader, criterion, task):
    correct = 0
    total = 0
    avg_test_loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for images, images_rotated, labels, cls_labels in testloader:
            if task == 'rotation':
              images, labels = images_rotated.to(device), labels.to(device)
            elif task == 'classification':
              images, labels = images.to(device), cls_labels.to(device)
            #######################################################################
            # TODO: Calculate outputs by running images through the network       #
            # The class with the highest energy is what we choose as prediction   #
            #######################################################################

            # Calculate outputs by running images through the network
            outputs = net(images)

            # Get predictions
            _, predicted = torch.max(outputs.data, 1)

            # Calculate total number of labels and correct predictions
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            #######################################################################
            #                           End of your code                          #
            #######################################################################
            avg_test_loss += criterion(outputs, labels)  / len(testloader)
    print('TESTING:')
    print(f'Accuracy of the network on the 10000 test images: {100 * correct / total:.2f} %')
    print(f'Average loss on the 10000 test images: {avg_test_loss:.3f}')

# %%
def adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs=30):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = init_lr * (0.1 ** (epoch // decay_epochs))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# # Train a ResNet18 on the rotation task (9 points)
#
# In this section, we will train a ResNet18 model **from scratch** on the rotation task. The input is a rotated image and the model predicts the rotation label. See the Data Setup section for details.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ### Notice: You should not use pretrained weights from ImageNet.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

net = resnet18(weights = None, num_classes=4) # Do not modify this line.
net = net.to(device)
print(net) # print your model and check the num_classes is correct
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=4, bias=True)
# )

# %%
import torch.nn as nn
import torch.optim as optim
################################################################################
# TODO: Define loss and optmizer functions                                     #
# Try any loss or optimizer function and learning rate to get better result    #
# hint: torch.nn and torch.optim                                               #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)
################################################################################
#                               End of your code                               #
################################################################################
criterion = criterion.to(device)

# %%
# Both the self-supervised rotation task and supervised CIFAR10 classification are
# trained with the CrossEntropyLoss, so we can use the training loop code.

def train(net, criterion, optimizer, num_epochs, decay_epochs, init_lr, task):

    for epoch in range(num_epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        running_correct = 0.0
        running_total = 0.0
        start_time = time.time()

        net.train()

        for i, (imgs, imgs_rotated, rotation_label, cls_label) in enumerate(trainloader, 0):
            adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs)
            ######################################################################################################
            # TODO: Set the data to the correct device; Different task will use different inputs and labels      #
            # TODO: Zero the parameter gradients                                                                 #
            # TODO: forward + backward + optimize                                                                #
            # TODO: Get predicted results                                                                        #
            ######################################################################################################
            # Set data to correct device and choose appropriate inputs/labels
            if task == 'rotation':
                images, labels = imgs_rotated.to(device), rotation_label.to(device)
            else:  # classification task
                images, labels = imgs.to(device), cls_label.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward + backward + optimize
            outputs = net(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Get predicted results
            _, predicted = torch.max(outputs.data, 1)
            ######################################################################################################
            #                               End of your code                                                     #
            ######################################################################################################


            # print statistics
            print_freq = 100
            running_loss += loss.item()

            # calc acc
            running_total += labels.size(0)
            running_correct += (predicted == labels).sum().item()

            if i % print_freq == (print_freq - 1):    # print every 2000 mini-batches
                print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / print_freq:.3f} acc: {100*running_correct / running_total:.2f} time: {time.time() - start_time:.2f}')
                running_loss, running_correct, running_total = 0.0, 0.0, 0.0
                start_time = time.time()
        ######################################################################################################
        # TODO: Run the run_test() function after each epoch; Set the model to the evaluation mode.          #
        ######################################################################################################

        # Run test after each epoch
        net.eval()  # Set the model to evaluation mode
        run_test(net, testloader, criterion, task)

        ######################################################################################################
        #                               End of your code                                                     #
        ######################################################################################################

    print('Finished Training')

# %%
train(net, criterion, optimizer, num_epochs=45, decay_epochs=15, init_lr=0.01, task='rotation')
################################
#     TODO: Save the model     #
################################
torch.save(net.state_dict(), 'rotation_model.pth')
################################
#      End of your code        #
################################
# Out:
# [1,   100] loss: 1.530 acc: 34.20 time: 11.07
# [1,   200] loss: 1.234 acc: 44.61 time: 7.74
# [1,   300] loss: 1.173 acc: 48.48 time: 9.28
# TESTING:
# Accuracy of the network on the 10000 test images: 52.03 %
# Average loss on the 10000 test images: 1.110
# [2,   100] loss: 1.155 acc: 49.53 time: 7.57
# [2,   200] loss: 1.103 acc: 52.09 time: 9.30
# [2,   300] loss: 1.094 acc: 52.69 time: 8.58
# TESTING:
# Accuracy of the network on the 10000 test images: 53.42 %
# Average loss on the 10000 test images: 1.077
# [3,   100] loss: 1.067 acc: 54.21 time: 9.34
# [3,   200] loss: 1.054 acc: 54.48 time: 8.89
# [3,   300] loss: 1.041 acc: 55.43 time: 8.13
# TESTING:
# Accuracy of the network on the 10000 test images: 58.60 %
# Average loss on the 10000 test images: 0.982
# [4,   100] loss: 1.016 acc: 56.77 time: 9.40
# [4,   200] loss: 0.999 acc: 57.30 time: 7.63
# [4,   300] loss: 0.985 acc: 57.90 time: 9.25
# TESTING:
# Accuracy of the network on the 10000 test images: 59.54 %
# Average loss on the 10000 test images: 0.954
# [5,   100] loss: 0.968 acc: 59.33 time: 7.77
# [5,   200] loss: 0.964 acc: 59.34 time: 9.24
# [5,   300] loss: 0.937 acc: 60.97 time: 8.13
# TESTING:
# Accuracy of the network on the 10000 test images: 61.56 %
# Average loss on the 10000 test images: 0.925
# [6,   100] loss: 0.921 acc: 61.49 time: 9.40
# [6,   200] loss: 0.925 acc: 61.51 time: 8.28
# [6,   300] loss: 0.925 acc: 60.89 time: 8.71
# TESTING:
# Accuracy of the network on the 10000 test images: 63.84 %
# Average loss on the 10000 test images: 0.860
# [7,   100] loss: 0.894 acc: 62.86 time: 8.53
# [7,   200] loss: 0.900 acc: 62.50 time: 8.50
# [7,   300] loss: 0.897 acc: 62.26 time: 9.28
# TESTING:
# Accuracy of the network on the 10000 test images: 64.34 %
# Average loss on the 10000 test images: 0.858
# [8,   100] loss: 0.863 acc: 64.34 time: 8.40
# [8,   200] loss: 0.884 acc: 63.23 time: 9.26
# [8,   300] loss: 0.860 acc: 63.75 time: 7.60
# TESTING:
# Accuracy of the network on the 10000 test images: 66.25 %
# Average loss on the 10000 test images: 0.821
# [9,   100] loss: 0.854 acc: 64.60 time: 9.44
# [9,   200] loss: 0.851 acc: 65.02 time: 7.67
# [9,   300] loss: 0.842 acc: 65.84 time: 9.35
# TESTING:
# Accuracy of the network on the 10000 test images: 67.29 %
# Average loss on the 10000 test images: 0.797
# [10,   100] loss: 0.824 acc: 66.13 time: 7.56
# [10,   200] loss: 0.828 acc: 66.30 time: 9.32
# [10,   300] loss: 0.817 acc: 66.51 time: 7.82
# TESTING:
# Accuracy of the network on the 10000 test images: 67.26 %
# Average loss on the 10000 test images: 0.807
# [11,   100] loss: 0.823 acc: 66.00 time: 9.47
# [11,   200] loss: 0.801 acc: 67.55 time: 8.18
# [11,   300] loss: 0.812 acc: 67.10 time: 8.76
# TESTING:
# Accuracy of the network on the 10000 test images: 67.87 %
# Average loss on the 10000 test images: 0.789
# [12,   100] loss: 0.804 acc: 67.34 time: 8.77
# [12,   200] loss: 0.799 acc: 67.77 time: 8.37
# [12,   300] loss: 0.793 acc: 67.40 time: 9.29
# TESTING:
# Accuracy of the network on the 10000 test images: 68.88 %
# Average loss on the 10000 test images: 0.769
# [13,   100] loss: 0.778 acc: 68.53 time: 8.12
# [13,   200] loss: 0.769 acc: 69.25 time: 9.31
# [13,   300] loss: 0.774 acc: 68.62 time: 8.08
# TESTING:
# Accuracy of the network on the 10000 test images: 70.16 %
# Average loss on the 10000 test images: 0.743
# [14,   100] loss: 0.764 acc: 68.95 time: 10.00
# [14,   200] loss: 0.774 acc: 68.82 time: 8.20
# [14,   300] loss: 0.758 acc: 69.47 time: 8.93
# TESTING:
# Accuracy of the network on the 10000 test images: 69.93 %
# Average loss on the 10000 test images: 0.731
# [15,   100] loss: 0.752 acc: 69.84 time: 8.79
# [15,   200] loss: 0.738 acc: 70.40 time: 9.16
# [15,   300] loss: 0.740 acc: 70.27 time: 9.67
# TESTING:
# Accuracy of the network on the 10000 test images: 71.93 %
# Average loss on the 10000 test images: 0.696
# [16,   100] loss: 0.688 acc: 72.20 time: 8.48
# [16,   200] loss: 0.665 acc: 73.65 time: 9.42
# [16,   300] loss: 0.673 acc: 73.02 time: 8.88
# TESTING:
# Accuracy of the network on the 10000 test images: 74.35 %
# Average loss on the 10000 test images: 0.635
# [17,   100] loss: 0.669 acc: 73.41 time: 9.35
# [17,   200] loss: 0.657 acc: 74.02 time: 9.45
# [17,   300] loss: 0.647 acc: 74.61 time: 7.59
# TESTING:
# Accuracy of the network on the 10000 test images: 75.04 %
# Average loss on the 10000 test images: 0.625
# [18,   100] loss: 0.635 acc: 74.70 time: 9.66
# [18,   200] loss: 0.653 acc: 74.16 time: 8.27
# [18,   300] loss: 0.638 acc: 75.07 time: 9.13
# TESTING:
# Accuracy of the network on the 10000 test images: 75.43 %
# Average loss on the 10000 test images: 0.618
# [19,   100] loss: 0.634 acc: 75.16 time: 8.37
# [19,   200] loss: 0.641 acc: 74.91 time: 9.02
# [19,   300] loss: 0.628 acc: 75.31 time: 9.31
# TESTING:
# Accuracy of the network on the 10000 test images: 76.08 %
# Average loss on the 10000 test images: 0.614
# [20,   100] loss: 0.637 acc: 75.16 time: 9.82
# [20,   200] loss: 0.643 acc: 74.79 time: 9.19
# [20,   300] loss: 0.612 acc: 75.70 time: 7.52
# TESTING:
# Accuracy of the network on the 10000 test images: 76.08 %
# Average loss on the 10000 test images: 0.608
# [21,   100] loss: 0.617 acc: 75.87 time: 9.49
# [21,   200] loss: 0.631 acc: 75.36 time: 7.72
# [21,   300] loss: 0.630 acc: 75.21 time: 9.07
# TESTING:
# Accuracy of the network on the 10000 test images: 76.55 %
# Average loss on the 10000 test images: 0.599
# [22,   100] loss: 0.622 acc: 75.34 time: 8.05
# [22,   200] loss: 0.619 acc: 75.88 time: 9.05
# [22,   300] loss: 0.614 acc: 75.79 time: 9.01
# TESTING:
# Accuracy of the network on the 10000 test images: 76.47 %
# Average loss on the 10000 test images: 0.593
# [23,   100] loss: 0.606 acc: 76.01 time: 8.66
# [23,   200] loss: 0.615 acc: 75.64 time: 9.24
# [23,   300] loss: 0.617 acc: 75.90 time: 7.35
# TESTING:
# Accuracy of the network on the 10000 test images: 76.17 %
# Average loss on the 10000 test images: 0.598
# [24,   100] loss: 0.610 acc: 75.89 time: 9.23
# [24,   200] loss: 0.595 acc: 76.34 time: 7.42
# [24,   300] loss: 0.621 acc: 75.41 time: 9.17
# TESTING:
# Accuracy of the network on the 10000 test images: 76.04 %
# Average loss on the 10000 test images: 0.592
# [25,   100] loss: 0.596 acc: 76.59 time: 7.53
# [25,   200] loss: 0.603 acc: 76.46 time: 10.89
# [25,   300] loss: 0.615 acc: 75.61 time: 8.12
# TESTING:
# Accuracy of the network on the 10000 test images: 76.96 %
# Average loss on the 10000 test images: 0.586
# [26,   100] loss: 0.601 acc: 76.36 time: 9.31
# [26,   200] loss: 0.598 acc: 76.57 time: 8.13
# [26,   300] loss: 0.606 acc: 76.05 time: 8.23
# TESTING:
# Accuracy of the network on the 10000 test images: 77.06 %
# Average loss on the 10000 test images: 0.581
# [27,   100] loss: 0.592 acc: 76.73 time: 8.67
# [27,   200] loss: 0.591 acc: 76.83 time: 8.80
# [27,   300] loss: 0.593 acc: 76.38 time: 9.32
# TESTING:
# Accuracy of the network on the 10000 test images: 77.24 %
# Average loss on the 10000 test images: 0.578
# [28,   100] loss: 0.594 acc: 76.45 time: 8.07
# [28,   200] loss: 0.579 acc: 77.49 time: 9.61
# [28,   300] loss: 0.590 acc: 76.33 time: 8.20
# TESTING:
# Accuracy of the network on the 10000 test images: 77.42 %
# Average loss on the 10000 test images: 0.567
# [29,   100] loss: 0.584 acc: 77.48 time: 9.52
# [29,   200] loss: 0.593 acc: 77.25 time: 8.59
# [29,   300] loss: 0.579 acc: 77.34 time: 8.33
# TESTING:
# Accuracy of the network on the 10000 test images: 77.39 %
# Average loss on the 10000 test images: 0.571
# [30,   100] loss: 0.584 acc: 76.98 time: 9.60
# [30,   200] loss: 0.586 acc: 76.83 time: 7.69
# [30,   300] loss: 0.584 acc: 77.05 time: 9.21
# TESTING:
# Accuracy of the network on the 10000 test images: 77.50 %
# Average loss on the 10000 test images: 0.568
# [31,   100] loss: 0.568 acc: 77.95 time: 7.77
# [31,   200] loss: 0.560 acc: 77.99 time: 9.27
# [31,   300] loss: 0.575 acc: 77.62 time: 7.86
# TESTING:
# Accuracy of the network on the 10000 test images: 77.99 %
# Average loss on the 10000 test images: 0.562
# [32,   100] loss: 0.566 acc: 77.96 time: 9.52
# [32,   200] loss: 0.576 acc: 77.56 time: 10.90
# [32,   300] loss: 0.559 acc: 77.95 time: 7.45
# TESTING:
# Accuracy of the network on the 10000 test images: 78.04 %
# Average loss on the 10000 test images: 0.557
# [33,   100] loss: 0.572 acc: 77.73 time: 9.99
# [33,   200] loss: 0.560 acc: 78.59 time: 7.87
# [33,   300] loss: 0.568 acc: 77.86 time: 9.89
# TESTING:
# Accuracy of the network on the 10000 test images: 78.25 %
# Average loss on the 10000 test images: 0.555
# [34,   100] loss: 0.577 acc: 77.30 time: 7.84
# [34,   200] loss: 0.566 acc: 78.22 time: 9.02
# [34,   300] loss: 0.561 acc: 77.98 time: 8.87
# TESTING:
# Accuracy of the network on the 10000 test images: 77.70 %
# Average loss on the 10000 test images: 0.559
# [35,   100] loss: 0.559 acc: 78.16 time: 9.89
# [35,   200] loss: 0.541 acc: 78.73 time: 9.14
# [35,   300] loss: 0.581 acc: 77.48 time: 7.34
# TESTING:
# Accuracy of the network on the 10000 test images: 77.68 %
# Average loss on the 10000 test images: 0.560
# [36,   100] loss: 0.571 acc: 77.81 time: 9.31
# [36,   200] loss: 0.554 acc: 78.38 time: 8.32
# [36,   300] loss: 0.557 acc: 78.07 time: 9.17
# TESTING:
# Accuracy of the network on the 10000 test images: 78.13 %
# Average loss on the 10000 test images: 0.557
# [37,   100] loss: 0.559 acc: 77.91 time: 7.50
# [37,   200] loss: 0.551 acc: 78.33 time: 9.04
# [37,   300] loss: 0.567 acc: 77.93 time: 7.87
# TESTING:
# Accuracy of the network on the 10000 test images: 78.55 %
# Average loss on the 10000 test images: 0.557
# [38,   100] loss: 0.560 acc: 77.85 time: 9.18
# [38,   200] loss: 0.556 acc: 78.27 time: 8.17
# [38,   300] loss: 0.572 acc: 77.56 time: 8.53
# TESTING:
# Accuracy of the network on the 10000 test images: 78.25 %
# Average loss on the 10000 test images: 0.553
# [39,   100] loss: 0.557 acc: 78.38 time: 8.45
# [39,   200] loss: 0.559 acc: 78.09 time: 8.18
# [39,   300] loss: 0.560 acc: 78.41 time: 9.06
# TESTING:
# Accuracy of the network on the 10000 test images: 77.92 %
# Average loss on the 10000 test images: 0.555
# [40,   100] loss: 0.555 acc: 78.25 time: 8.19
# [40,   200] loss: 0.562 acc: 78.47 time: 9.10
# [40,   300] loss: 0.552 acc: 78.45 time: 7.35
# TESTING:
# Accuracy of the network on the 10000 test images: 78.01 %
# Average loss on the 10000 test images: 0.558
# [41,   100] loss: 0.570 acc: 77.87 time: 9.28
# [41,   200] loss: 0.545 acc: 78.64 time: 7.33
# [41,   300] loss: 0.558 acc: 77.71 time: 8.99
# TESTING:
# Accuracy of the network on the 10000 test images: 78.05 %
# Average loss on the 10000 test images: 0.553
# [42,   100] loss: 0.576 acc: 77.51 time: 7.60
# [42,   200] loss: 0.556 acc: 78.38 time: 9.03
# [42,   300] loss: 0.556 acc: 78.00 time: 8.82
# TESTING:
# Accuracy of the network on the 10000 test images: 78.27 %
# Average loss on the 10000 test images: 0.549
# [43,   100] loss: 0.555 acc: 78.66 time: 9.22
# [43,   200] loss: 0.570 acc: 77.54 time: 8.86
# [43,   300] loss: 0.548 acc: 78.62 time: 7.68
# TESTING:
# Accuracy of the network on the 10000 test images: 78.55 %
# Average loss on the 10000 test images: 0.551
# [44,   100] loss: 0.547 acc: 78.68 time: 10.45
# [44,   200] loss: 0.570 acc: 78.05 time: 10.73
# [44,   300] loss: 0.556 acc: 78.58 time: 8.66
# TESTING:
# Accuracy of the network on the 10000 test images: 78.42 %
# Average loss on the 10000 test images: 0.547
# [45,   100] loss: 0.560 acc: 77.99 time: 8.19
# [45,   200] loss: 0.562 acc: 77.82 time: 8.33
# [45,   300] loss: 0.560 acc: 78.13 time: 8.97
# TESTING:
# Accuracy of the network on the 10000 test images: 77.99 %
# Average loss on the 10000 test images: 0.553
# Finished Training

# %% [markdown]
# ## Fine-tuning on the pre-trained model (9 points)
#
# In this section, we will load the ResNet18 model pre-trained on the rotation task and fine-tune on the classification task. We will freeze all previous layers except for the 'layer4' block and 'fc' layer.
#
# **Then we will use the trained model from rotation task as the pretrained weights. Notice, you should not use the pretrained weights from ImageNet.**

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#####################################################
#     TODO: Load the pre-trained ResNet18 model     #
#####################################################
# Create a new ResNet18 with the correct number of output classes
net = resnet18(pretrained=False, num_classes=4)  # Set num_classes to 4 for rotation task

# Load the weights from rotation task
net.load_state_dict(torch.load('rotation_model.pth'))

print(net) # print your model and check the num_classes is correct
####################################################
#                End of your code                  #
####################################################
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# <ipython-input-13-e22f326e9e1b>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(torch.load('rotation_model.pth'))
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=4, bias=True)
# )

# %%
#################################################################################################
#   TODO: Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable     #
#################################################################################################
net.fc = nn.Linear(net.fc.in_features, 10)  # Modify fc layer for CIFAR10 (10 classes)

#Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable
for name, param in net.named_parameters():
    if 'layer4' not in name and 'fc' not in name:
        param.requires_grad = False

net = net.to(device)
#################################################################################################
#                                          End of your code                                     #
#################################################################################################

# %%
# Print all the trainable parameters
params_to_update = net.parameters()
print("Params to learn:")
params_to_update = []
for name,param in net.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
# TODO: Define criterion and optimizer
# Note that your optimizer only needs to update the parameters that are trainable.
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam([p for p in net.parameters() if p.requires_grad], lr=0.001)

# %%
train(net, criterion, optimizer, num_epochs=20, decay_epochs=10, init_lr=0.01, task='classification')
# Out:
# [1,   100] loss: 1.770 acc: 34.39 time: 8.02
# [1,   200] loss: 1.506 acc: 45.37 time: 7.99
# [1,   300] loss: 1.437 acc: 47.62 time: 8.29
# TESTING:
# Accuracy of the network on the 10000 test images: 49.77 %
# Average loss on the 10000 test images: 1.427
# [2,   100] loss: 1.372 acc: 49.46 time: 8.96
# [2,   200] loss: 1.381 acc: 49.84 time: 7.82
# [2,   300] loss: 1.336 acc: 51.38 time: 8.13
# TESTING:
# Accuracy of the network on the 10000 test images: 53.60 %
# Average loss on the 10000 test images: 1.295
# [3,   100] loss: 1.316 acc: 52.58 time: 7.27
# [3,   200] loss: 1.328 acc: 52.02 time: 8.58
# [3,   300] loss: 1.316 acc: 52.20 time: 8.06
# TESTING:
# Accuracy of the network on the 10000 test images: 54.63 %
# Average loss on the 10000 test images: 1.260
# [4,   100] loss: 1.306 acc: 52.38 time: 8.84
# [4,   200] loss: 1.294 acc: 53.41 time: 7.41
# [4,   300] loss: 1.285 acc: 53.73 time: 8.19
# TESTING:
# Accuracy of the network on the 10000 test images: 56.08 %
# Average loss on the 10000 test images: 1.227
# [5,   100] loss: 1.278 acc: 54.05 time: 7.14
# [5,   200] loss: 1.258 acc: 54.77 time: 8.57
# [5,   300] loss: 1.259 acc: 54.68 time: 7.18
# TESTING:
# Accuracy of the network on the 10000 test images: 56.29 %
# Average loss on the 10000 test images: 1.235
# [6,   100] loss: 1.258 acc: 54.91 time: 8.90
# [6,   200] loss: 1.260 acc: 54.83 time: 6.94
# [6,   300] loss: 1.261 acc: 54.98 time: 8.51
# TESTING:
# Accuracy of the network on the 10000 test images: 56.20 %
# Average loss on the 10000 test images: 1.233
# [7,   100] loss: 1.239 acc: 55.34 time: 7.17
# [7,   200] loss: 1.245 acc: 55.34 time: 8.65
# [7,   300] loss: 1.231 acc: 55.45 time: 6.93
# TESTING:
# Accuracy of the network on the 10000 test images: 56.39 %
# Average loss on the 10000 test images: 1.204
# [8,   100] loss: 1.227 acc: 55.80 time: 8.79
# [8,   200] loss: 1.232 acc: 56.02 time: 6.95
# [8,   300] loss: 1.228 acc: 56.03 time: 9.34
# TESTING:
# Accuracy of the network on the 10000 test images: 56.97 %
# Average loss on the 10000 test images: 1.219
# [9,   100] loss: 1.227 acc: 55.94 time: 7.03
# [9,   200] loss: 1.236 acc: 55.40 time: 8.75
# [9,   300] loss: 1.228 acc: 55.86 time: 8.02
# TESTING:
# Accuracy of the network on the 10000 test images: 58.29 %
# Average loss on the 10000 test images: 1.163
# [10,   100] loss: 1.199 acc: 57.17 time: 9.09
# [10,   200] loss: 1.209 acc: 56.42 time: 7.36
# [10,   300] loss: 1.221 acc: 55.86 time: 8.40
# TESTING:
# Accuracy of the network on the 10000 test images: 57.07 %
# Average loss on the 10000 test images: 1.210
# [11,   100] loss: 1.188 acc: 57.57 time: 7.11
# [11,   200] loss: 1.168 acc: 57.61 time: 8.66
# [11,   300] loss: 1.151 acc: 58.59 time: 8.87
# TESTING:
# Accuracy of the network on the 10000 test images: 59.68 %
# Average loss on the 10000 test images: 1.131
# [12,   100] loss: 1.142 acc: 58.72 time: 8.79
# [12,   200] loss: 1.161 acc: 57.82 time: 7.35
# [12,   300] loss: 1.147 acc: 59.14 time: 10.11
# TESTING:
# Accuracy of the network on the 10000 test images: 60.16 %
# Average loss on the 10000 test images: 1.121
# [13,   100] loss: 1.142 acc: 59.00 time: 7.78
# [13,   200] loss: 1.143 acc: 58.98 time: 8.07
# [13,   300] loss: 1.150 acc: 58.48 time: 8.30
# TESTING:
# Accuracy of the network on the 10000 test images: 59.84 %
# Average loss on the 10000 test images: 1.121
# [14,   100] loss: 1.122 acc: 59.46 time: 8.77
# [14,   200] loss: 1.154 acc: 58.68 time: 8.78
# [14,   300] loss: 1.142 acc: 59.01 time: 7.77
# TESTING:
# Accuracy of the network on the 10000 test images: 60.01 %
# Average loss on the 10000 test images: 1.117
# [15,   100] loss: 1.129 acc: 59.00 time: 10.63
# [15,   200] loss: 1.121 acc: 59.73 time: 7.48
# [15,   300] loss: 1.129 acc: 59.05 time: 8.82
# TESTING:
# Accuracy of the network on the 10000 test images: 60.07 %
# Average loss on the 10000 test images: 1.118
# [16,   100] loss: 1.138 acc: 59.12 time: 7.59
# [16,   200] loss: 1.129 acc: 59.34 time: 9.16
# [16,   300] loss: 1.137 acc: 58.86 time: 7.51
# TESTING:
# Accuracy of the network on the 10000 test images: 60.28 %
# Average loss on the 10000 test images: 1.110
# [17,   100] loss: 1.109 acc: 60.15 time: 9.57
# [17,   200] loss: 1.106 acc: 60.11 time: 11.60
# [17,   300] loss: 1.152 acc: 58.54 time: 7.00
# TESTING:
# Accuracy of the network on the 10000 test images: 60.37 %
# Average loss on the 10000 test images: 1.104
# [18,   100] loss: 1.107 acc: 60.27 time: 9.11
# [18,   200] loss: 1.125 acc: 59.62 time: 7.20
# [18,   300] loss: 1.131 acc: 59.46 time: 8.79
# TESTING:
# Accuracy of the network on the 10000 test images: 60.20 %
# Average loss on the 10000 test images: 1.106
# [19,   100] loss: 1.124 acc: 59.36 time: 7.20
# [19,   200] loss: 1.110 acc: 59.15 time: 9.08
# [19,   300] loss: 1.126 acc: 59.31 time: 7.05
# TESTING:
# Accuracy of the network on the 10000 test images: 60.48 %
# Average loss on the 10000 test images: 1.106
# [20,   100] loss: 1.124 acc: 59.39 time: 9.17
# [20,   200] loss: 1.120 acc: 59.79 time: 7.15
# [20,   300] loss: 1.100 acc: 61.06 time: 8.96
# TESTING:
# Accuracy of the network on the 10000 test images: 60.56 %
# Average loss on the 10000 test images: 1.097
# Finished Training

# %% [markdown]
# ## Fine-tuning on the randomly initialized model (9 points)
# In this section, we will randomly initialize a ResNet18 model and fine-tune on the classification task. We will freeze all previous layers except for the 'layer4' block and 'fc' layer.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18
#################################################
# TODO: Randomly initialize a ResNet18 model    #
#################################################
net = resnet18(pretrained=False)
print(net) # print your model and check the num_classes is correct
#################################################
#              End of your code                 #
#################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
#################################################################################################
# TODO: Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable       #
# To do this, you should set requires_grad=False for the frozen layers.                         #
#################################################################################################
net.fc = nn.Linear(net.fc.in_features, 10)

#Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable
for name, param in net.named_parameters():
    if 'layer4' not in name and 'fc' not in name:
        param.requires_grad = False

net = net.to(device)
#################################################################################################
#                                          End of your code                                     #
#################################################################################################

# %%
# Print all the trainable parameters
params_to_update = net.parameters()
print("Params to learn:")
params_to_update = []
for name,param in net.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
# TODO: Define criterion and optimizer
# Note that your optimizer only needs to update the parameters that are trainable.
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam([p for p in net.parameters() if p.requires_grad], lr=0.001)

# %%
train(net, criterion, optimizer, num_epochs=20, decay_epochs=10, init_lr=0.01, task='classification')
# Out:
# [1,   100] loss: 2.245 acc: 25.01 time: 9.15
# [1,   200] loss: 1.940 acc: 30.27 time: 7.25
# [1,   300] loss: 1.874 acc: 32.41 time: 8.51
# TESTING:
# Accuracy of the network on the 10000 test images: 36.73 %
# Average loss on the 10000 test images: 1.750
# [2,   100] loss: 1.807 acc: 34.70 time: 7.23
# [2,   200] loss: 1.788 acc: 34.95 time: 8.75
# [2,   300] loss: 1.775 acc: 35.98 time: 7.74
# TESTING:
# Accuracy of the network on the 10000 test images: 38.52 %
# Average loss on the 10000 test images: 1.694
# [3,   100] loss: 1.754 acc: 36.27 time: 8.96
# [3,   200] loss: 1.755 acc: 36.77 time: 7.26
# [3,   300] loss: 1.750 acc: 37.52 time: 8.56
# TESTING:
# Accuracy of the network on the 10000 test images: 41.04 %
# Average loss on the 10000 test images: 1.642
# [4,   100] loss: 1.717 acc: 38.02 time: 7.30
# [4,   200] loss: 1.713 acc: 39.03 time: 8.77
# [4,   300] loss: 1.714 acc: 38.21 time: 7.57
# TESTING:
# Accuracy of the network on the 10000 test images: 41.63 %
# Average loss on the 10000 test images: 1.628
# [5,   100] loss: 1.715 acc: 38.58 time: 9.20
# [5,   200] loss: 1.709 acc: 38.67 time: 7.27
# [5,   300] loss: 1.699 acc: 38.81 time: 8.93
# TESTING:
# Accuracy of the network on the 10000 test images: 41.23 %
# Average loss on the 10000 test images: 1.622
# [6,   100] loss: 1.690 acc: 39.06 time: 7.45
# [6,   200] loss: 1.694 acc: 38.50 time: 9.08
# [6,   300] loss: 1.676 acc: 39.49 time: 8.30
# TESTING:
# Accuracy of the network on the 10000 test images: 41.77 %
# Average loss on the 10000 test images: 1.620
# [7,   100] loss: 1.675 acc: 40.05 time: 9.22
# [7,   200] loss: 1.657 acc: 40.78 time: 7.99
# [7,   300] loss: 1.658 acc: 40.58 time: 8.63
# TESTING:
# Accuracy of the network on the 10000 test images: 41.86 %
# Average loss on the 10000 test images: 1.611
# [8,   100] loss: 1.659 acc: 40.23 time: 7.74
# [8,   200] loss: 1.658 acc: 40.02 time: 8.46
# [8,   300] loss: 1.660 acc: 40.32 time: 8.36
# TESTING:
# Accuracy of the network on the 10000 test images: 43.09 %
# Average loss on the 10000 test images: 1.586
# [9,   100] loss: 1.640 acc: 40.96 time: 9.01
# [9,   200] loss: 1.656 acc: 40.65 time: 8.52
# [9,   300] loss: 1.654 acc: 40.84 time: 7.87
# TESTING:
# Accuracy of the network on the 10000 test images: 43.93 %
# Average loss on the 10000 test images: 1.571
# [10,   100] loss: 1.649 acc: 40.77 time: 8.79
# [10,   200] loss: 1.659 acc: 40.40 time: 7.92
# [10,   300] loss: 1.639 acc: 41.23 time: 9.15
# TESTING:
# Accuracy of the network on the 10000 test images: 43.62 %
# Average loss on the 10000 test images: 1.585
# [11,   100] loss: 1.611 acc: 42.12 time: 7.96
# [11,   200] loss: 1.581 acc: 43.43 time: 8.92
# [11,   300] loss: 1.593 acc: 42.82 time: 7.36
# TESTING:
# Accuracy of the network on the 10000 test images: 45.21 %
# Average loss on the 10000 test images: 1.532
# [12,   100] loss: 1.575 acc: 43.37 time: 9.07
# [12,   200] loss: 1.591 acc: 43.08 time: 7.14
# [12,   300] loss: 1.580 acc: 43.33 time: 8.67
# TESTING:
# Accuracy of the network on the 10000 test images: 45.44 %
# Average loss on the 10000 test images: 1.523
# [13,   100] loss: 1.576 acc: 43.55 time: 8.03
# [13,   200] loss: 1.558 acc: 44.48 time: 9.00
# [13,   300] loss: 1.593 acc: 43.12 time: 6.93
# TESTING:
# Accuracy of the network on the 10000 test images: 46.00 %
# Average loss on the 10000 test images: 1.517
# [14,   100] loss: 1.560 acc: 44.05 time: 9.23
# [14,   200] loss: 1.559 acc: 43.99 time: 7.34
# [14,   300] loss: 1.564 acc: 44.00 time: 8.91
# TESTING:
# Accuracy of the network on the 10000 test images: 45.81 %
# Average loss on the 10000 test images: 1.514
# [15,   100] loss: 1.557 acc: 44.35 time: 7.65
# [15,   200] loss: 1.549 acc: 44.31 time: 8.87
# [15,   300] loss: 1.548 acc: 44.48 time: 7.32
# TESTING:
# Accuracy of the network on the 10000 test images: 46.41 %
# Average loss on the 10000 test images: 1.506
# [16,   100] loss: 1.554 acc: 44.15 time: 9.19
# [16,   200] loss: 1.551 acc: 44.61 time: 7.21
# [16,   300] loss: 1.560 acc: 44.24 time: 9.03
# TESTING:
# Accuracy of the network on the 10000 test images: 46.49 %
# Average loss on the 10000 test images: 1.501
# [17,   100] loss: 1.556 acc: 44.23 time: 7.33
# [17,   200] loss: 1.551 acc: 44.55 time: 9.19
# [17,   300] loss: 1.558 acc: 44.73 time: 7.19
# TESTING:
# Accuracy of the network on the 10000 test images: 46.21 %
# Average loss on the 10000 test images: 1.504
# [18,   100] loss: 1.534 acc: 44.76 time: 8.98
# [18,   200] loss: 1.545 acc: 44.11 time: 7.12
# [18,   300] loss: 1.555 acc: 44.31 time: 8.70
# TESTING:
# Accuracy of the network on the 10000 test images: 46.74 %
# Average loss on the 10000 test images: 1.498
# [19,   100] loss: 1.530 acc: 44.78 time: 7.34
# [19,   200] loss: 1.555 acc: 44.00 time: 8.80
# [19,   300] loss: 1.545 acc: 44.64 time: 7.22
# TESTING:
# Accuracy of the network on the 10000 test images: 46.80 %
# Average loss on the 10000 test images: 1.491
# [20,   100] loss: 1.533 acc: 44.94 time: 8.97
# [20,   200] loss: 1.531 acc: 44.94 time: 7.23
# [20,   300] loss: 1.532 acc: 44.92 time: 8.86
# TESTING:
# Accuracy of the network on the 10000 test images: 47.10 %
# Average loss on the 10000 test images: 1.488
# Finished Training

# %% [markdown]
# ## Supervised training on the pre-trained model (9 points)
# In this section, we will load the ResNet18 model pre-trained on the rotation task and re-train the whole model on the classification task.
#
# **Then we will use the trained model from rotation task as the pretrained weights. Notice, you should not use the pretrained weights from ImageNet.**

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#####################################################
#     TODO: Load the pre-trained ResNet18 model     #
#####################################################
net = resnet18(weights=None, num_classes=4)
net.load_state_dict(torch.load('rotation_model.pth'))

net.fc = nn.Linear(net.fc.in_features, 10)
net = net.to(device)
print(net) # print your model and check the num_classes is correct
#####################################################
#                End of your code                   #
#####################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
# <ipython-input-23-72e9ab1074b5>:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(torch.load('rotation_model.pth'))

# %%
# TODO: Define criterion and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
train(net, criterion, optimizer, num_epochs=20, decay_epochs=10, init_lr=0.01, task='classification')
# Out:
# [1,   100] loss: 1.473 acc: 46.67 time: 9.54
# [1,   200] loss: 1.173 acc: 57.89 time: 7.55
# [1,   300] loss: 1.089 acc: 61.63 time: 9.33
# TESTING:
# Accuracy of the network on the 10000 test images: 67.13 %
# Average loss on the 10000 test images: 0.942
# [2,   100] loss: 0.945 acc: 67.16 time: 7.94
# [2,   200] loss: 0.937 acc: 67.20 time: 9.08
# [2,   300] loss: 0.893 acc: 69.23 time: 8.94
# TESTING:
# Accuracy of the network on the 10000 test images: 71.29 %
# Average loss on the 10000 test images: 0.840
# [3,   100] loss: 0.830 acc: 71.19 time: 9.04
# [3,   200] loss: 0.812 acc: 71.91 time: 9.03
# [3,   300] loss: 0.812 acc: 72.12 time: 7.73
# TESTING:
# Accuracy of the network on the 10000 test images: 73.69 %
# Average loss on the 10000 test images: 0.751
# [4,   100] loss: 0.777 acc: 73.51 time: 9.47
# [4,   200] loss: 0.757 acc: 74.06 time: 7.72
# [4,   300] loss: 0.735 acc: 74.61 time: 9.35
# TESTING:
# Accuracy of the network on the 10000 test images: 75.09 %
# Average loss on the 10000 test images: 0.714
# [5,   100] loss: 0.686 acc: 76.05 time: 7.68
# [5,   200] loss: 0.693 acc: 75.92 time: 9.54
# [5,   300] loss: 0.696 acc: 76.38 time: 8.45
# TESTING:
# Accuracy of the network on the 10000 test images: 75.24 %
# Average loss on the 10000 test images: 0.708
# [6,   100] loss: 0.664 acc: 77.16 time: 9.48
# [6,   200] loss: 0.654 acc: 77.38 time: 9.07
# [6,   300] loss: 0.673 acc: 76.64 time: 7.92
# TESTING:
# Accuracy of the network on the 10000 test images: 78.00 %
# Average loss on the 10000 test images: 0.639
# [7,   100] loss: 0.620 acc: 78.66 time: 9.38
# [7,   200] loss: 0.639 acc: 77.45 time: 7.63
# [7,   300] loss: 0.623 acc: 78.73 time: 9.30
# TESTING:
# Accuracy of the network on the 10000 test images: 78.18 %
# Average loss on the 10000 test images: 0.641
# [8,   100] loss: 0.587 acc: 79.73 time: 7.55
# [8,   200] loss: 0.593 acc: 79.60 time: 9.11
# [8,   300] loss: 0.587 acc: 79.72 time: 7.61
# TESTING:
# Accuracy of the network on the 10000 test images: 77.94 %
# Average loss on the 10000 test images: 0.658
# [9,   100] loss: 0.575 acc: 80.36 time: 9.33
# [9,   200] loss: 0.576 acc: 79.91 time: 7.75
# [9,   300] loss: 0.566 acc: 80.28 time: 8.90
# TESTING:
# Accuracy of the network on the 10000 test images: 79.92 %
# Average loss on the 10000 test images: 0.607
# [10,   100] loss: 0.543 acc: 81.33 time: 8.20
# [10,   200] loss: 0.540 acc: 81.30 time: 8.38
# [10,   300] loss: 0.560 acc: 80.80 time: 9.09
# TESTING:
# Accuracy of the network on the 10000 test images: 80.10 %
# Average loss on the 10000 test images: 0.577
# [11,   100] loss: 0.471 acc: 83.50 time: 8.81
# [11,   200] loss: 0.445 acc: 84.51 time: 9.04
# [11,   300] loss: 0.429 acc: 85.05 time: 7.44
# TESTING:
# Accuracy of the network on the 10000 test images: 82.51 %
# Average loss on the 10000 test images: 0.511
# [12,   100] loss: 0.409 acc: 85.45 time: 9.42
# [12,   200] loss: 0.423 acc: 85.14 time: 7.60
# [12,   300] loss: 0.420 acc: 85.21 time: 9.09
# TESTING:
# Accuracy of the network on the 10000 test images: 82.68 %
# Average loss on the 10000 test images: 0.505
# [13,   100] loss: 0.412 acc: 85.57 time: 7.71
# [13,   200] loss: 0.414 acc: 85.46 time: 8.98
# [13,   300] loss: 0.399 acc: 85.98 time: 7.69
# TESTING:
# Accuracy of the network on the 10000 test images: 83.05 %
# Average loss on the 10000 test images: 0.501
# [14,   100] loss: 0.396 acc: 86.02 time: 9.34
# [14,   200] loss: 0.396 acc: 85.98 time: 7.86
# [14,   300] loss: 0.398 acc: 86.12 time: 8.48
# TESTING:
# Accuracy of the network on the 10000 test images: 83.24 %
# Average loss on the 10000 test images: 0.495
# [15,   100] loss: 0.382 acc: 86.88 time: 8.16
# [15,   200] loss: 0.390 acc: 86.46 time: 8.48
# [15,   300] loss: 0.387 acc: 86.51 time: 9.00
# TESTING:
# Accuracy of the network on the 10000 test images: 83.30 %
# Average loss on the 10000 test images: 0.491
# [16,   100] loss: 0.365 acc: 87.37 time: 8.86
# [16,   200] loss: 0.362 acc: 87.42 time: 9.09
# [16,   300] loss: 0.390 acc: 86.68 time: 7.33
# TESTING:
# Accuracy of the network on the 10000 test images: 83.67 %
# Average loss on the 10000 test images: 0.490
# [17,   100] loss: 0.365 acc: 87.28 time: 9.28
# [17,   200] loss: 0.373 acc: 87.12 time: 7.66
# [17,   300] loss: 0.372 acc: 87.00 time: 9.04
# TESTING:
# Accuracy of the network on the 10000 test images: 83.74 %
# Average loss on the 10000 test images: 0.488
# [18,   100] loss: 0.369 acc: 87.30 time: 7.68
# [18,   200] loss: 0.354 acc: 87.61 time: 9.17
# [18,   300] loss: 0.375 acc: 86.98 time: 7.29
# TESTING:
# Accuracy of the network on the 10000 test images: 83.74 %
# Average loss on the 10000 test images: 0.487
# [19,   100] loss: 0.363 acc: 87.38 time: 9.27
# [19,   200] loss: 0.364 acc: 87.40 time: 7.43
# [19,   300] loss: 0.358 acc: 87.58 time: 9.33
# TESTING:
# Accuracy of the network on the 10000 test images: 83.83 %
# Average loss on the 10000 test images: 0.486
# [20,   100] loss: 0.343 acc: 87.80 time: 7.76
# [20,   200] loss: 0.347 acc: 87.81 time: 9.23
# [20,   300] loss: 0.370 acc: 87.12 time: 8.75
# TESTING:
# Accuracy of the network on the 10000 test images: 83.76 %
# Average loss on the 10000 test images: 0.488
# Finished Training

# %% [markdown]
# ## Supervised training on the randomly initialized model (9 points)
# In this section, we will randomly initialize a ResNet18 model and re-train the whole model on the classification task.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#################################################
# TODO: Randomly initialize a ResNet18 model    #
#################################################
net = resnet18(weights=None, num_classes=10)
net = net.to(device)
print(net) # print your model and check the num_classes is correct
#################################################
#              End of your code                 #
#################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# TODO: Define criterion and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
train(net, criterion, optimizer, num_epochs=20, decay_epochs=10, init_lr=0.01, task='classification')
# Out:
# [1,   100] loss: 2.295 acc: 21.30 time: 8.40
# [1,   200] loss: 1.845 acc: 32.30 time: 9.02
# [1,   300] loss: 1.760 acc: 35.46 time: 9.08
# TESTING:
# Accuracy of the network on the 10000 test images: 42.73 %
# Average loss on the 10000 test images: 1.566
# [2,   100] loss: 1.574 acc: 41.79 time: 8.68
# [2,   200] loss: 1.503 acc: 45.02 time: 9.34
# [2,   300] loss: 1.438 acc: 47.29 time: 7.71
# TESTING:
# Accuracy of the network on the 10000 test images: 50.25 %
# Average loss on the 10000 test images: 1.701
# [3,   100] loss: 1.321 acc: 51.60 time: 9.49
# [3,   200] loss: 1.308 acc: 52.58 time: 7.68
# [3,   300] loss: 1.233 acc: 55.77 time: 9.06
# TESTING:
# Accuracy of the network on the 10000 test images: 58.69 %
# Average loss on the 10000 test images: 1.145
# [4,   100] loss: 1.150 acc: 58.71 time: 7.67
# [4,   200] loss: 1.106 acc: 60.39 time: 9.05
# [4,   300] loss: 1.081 acc: 61.72 time: 8.22
# TESTING:
# Accuracy of the network on the 10000 test images: 60.55 %
# Average loss on the 10000 test images: 1.169
# [5,   100] loss: 1.030 acc: 63.91 time: 9.41
# [5,   200] loss: 0.995 acc: 64.65 time: 8.19
# [5,   300] loss: 0.980 acc: 64.98 time: 8.03
# TESTING:
# Accuracy of the network on the 10000 test images: 65.91 %
# Average loss on the 10000 test images: 0.975
# [6,   100] loss: 0.925 acc: 67.55 time: 8.72
# [6,   200] loss: 0.915 acc: 67.97 time: 8.05
# [6,   300] loss: 0.895 acc: 68.36 time: 9.28
# TESTING:
# Accuracy of the network on the 10000 test images: 70.15 %
# Average loss on the 10000 test images: 0.864
# [7,   100] loss: 0.853 acc: 69.91 time: 8.35
# [7,   200] loss: 0.856 acc: 69.63 time: 9.23
# [7,   300] loss: 0.840 acc: 70.86 time: 7.38
# TESTING:
# Accuracy of the network on the 10000 test images: 72.70 %
# Average loss on the 10000 test images: 0.820
# [8,   100] loss: 0.799 acc: 72.23 time: 9.36
# [8,   200] loss: 0.785 acc: 72.48 time: 7.48
# [8,   300] loss: 0.783 acc: 72.28 time: 9.31
# TESTING:
# Accuracy of the network on the 10000 test images: 73.37 %
# Average loss on the 10000 test images: 0.799
# [9,   100] loss: 0.743 acc: 74.02 time: 7.63
# [9,   200] loss: 0.752 acc: 74.09 time: 9.19
# [9,   300] loss: 0.733 acc: 74.09 time: 7.91
# TESTING:
# Accuracy of the network on the 10000 test images: 75.41 %
# Average loss on the 10000 test images: 0.721
# [10,   100] loss: 0.696 acc: 76.17 time: 9.24
# [10,   200] loss: 0.698 acc: 75.56 time: 7.67
# [10,   300] loss: 0.721 acc: 75.32 time: 8.66
# TESTING:
# Accuracy of the network on the 10000 test images: 75.73 %
# Average loss on the 10000 test images: 0.707
# [11,   100] loss: 0.595 acc: 79.36 time: 8.37
# [11,   200] loss: 0.593 acc: 79.49 time: 8.49
# [11,   300] loss: 0.568 acc: 80.02 time: 9.14
# TESTING:
# Accuracy of the network on the 10000 test images: 79.97 %
# Average loss on the 10000 test images: 0.582
# [12,   100] loss: 0.535 acc: 81.43 time: 8.52
# [12,   200] loss: 0.535 acc: 81.47 time: 9.03
# [12,   300] loss: 0.529 acc: 81.69 time: 7.56
# TESTING:
# Accuracy of the network on the 10000 test images: 80.31 %
# Average loss on the 10000 test images: 0.569
# [13,   100] loss: 0.515 acc: 82.20 time: 9.36
# [13,   200] loss: 0.522 acc: 81.89 time: 7.68
# [13,   300] loss: 0.517 acc: 82.02 time: 9.06
# TESTING:
# Accuracy of the network on the 10000 test images: 80.76 %
# Average loss on the 10000 test images: 0.557
# [14,   100] loss: 0.504 acc: 82.38 time: 7.51
# [14,   200] loss: 0.496 acc: 82.82 time: 9.01
# [14,   300] loss: 0.503 acc: 82.37 time: 8.23
# TESTING:
# Accuracy of the network on the 10000 test images: 81.07 %
# Average loss on the 10000 test images: 0.549
# [15,   100] loss: 0.480 acc: 83.10 time: 9.29
# [15,   200] loss: 0.480 acc: 83.19 time: 8.01
# [15,   300] loss: 0.507 acc: 82.32 time: 8.36
# TESTING:
# Accuracy of the network on the 10000 test images: 80.76 %
# Average loss on the 10000 test images: 0.552
# [16,   100] loss: 0.479 acc: 83.19 time: 8.14
# [16,   200] loss: 0.475 acc: 83.47 time: 8.30
# [16,   300] loss: 0.484 acc: 83.09 time: 9.05
# TESTING:
# Accuracy of the network on the 10000 test images: 81.23 %
# Average loss on the 10000 test images: 0.544
# [17,   100] loss: 0.464 acc: 83.83 time: 8.67
# [17,   200] loss: 0.461 acc: 83.79 time: 8.68
# [17,   300] loss: 0.483 acc: 82.56 time: 7.41
# TESTING:
# Accuracy of the network on the 10000 test images: 81.51 %
# Average loss on the 10000 test images: 0.540
# [18,   100] loss: 0.461 acc: 83.77 time: 8.66
# [18,   200] loss: 0.465 acc: 83.62 time: 7.60
# [18,   300] loss: 0.459 acc: 83.72 time: 8.96
# TESTING:
# Accuracy of the network on the 10000 test images: 81.72 %
# Average loss on the 10000 test images: 0.541
# [19,   100] loss: 0.450 acc: 84.03 time: 8.18
# [19,   200] loss: 0.435 acc: 84.70 time: 8.91
# [19,   300] loss: 0.456 acc: 84.08 time: 7.42
# TESTING:
# Accuracy of the network on the 10000 test images: 81.75 %
# Average loss on the 10000 test images: 0.539
# [20,   100] loss: 0.428 acc: 84.98 time: 9.23
# [20,   200] loss: 0.458 acc: 83.72 time: 7.44
# [20,   300] loss: 0.443 acc: 84.27 time: 9.07
# TESTING:
# Accuracy of the network on the 10000 test images: 81.92 %
# Average loss on the 10000 test images: 0.537
# Finished Training

# %% [markdown]
# # Write report (37 points)
#
# 本次作業主要有3個tasks需要大家完成，在A3.pdf中有希望大家達成的baseline **(不能低於baseline最多2%，沒有達到不會給全部分數)**，report的撰寫請大家根據以下要求完成，就請大家將嘗試的結果寫在report裡，祝大家順利！
#
# 1. (13 points) Train a ResNet18 on the Rotation task and report the test performance. Discuss why such a task helps in learning features that are generalizable to other visual tasks.
#
# 2. (12 points) Initializing from the Rotation model or from random weights, fine-tune only the weights of the final block of convolutional layers and linear layer on the supervised CIFAR10 classification task. Report the test results and compare the performance of these two models. Provide your observations and insights. You can also discuss how the performance of pre-trained models affects downstream tasks, the performance of fine-tuning different numbers of layers, and so on.
#
# 3. (12 points) Initializing from the Rotation model or from random weights, train the full network on the supervised CIFAR10 classification task. Report the test results and compare the performance of these two models. Provide your observations and insights.

# %% [markdown]
# # Extra Credit (13 points)
#
# 上面基本的code跟report最高可以拿到87分，這個加分部分並沒有要求同學們一定要做，若同學們想要獲得更高的分數可以根據以下的加分要求來獲得加分。
#
# - In Figure 5(b) from the Gidaris et al. paper, the authors show a plot of CIFAR10 classification performance vs. number of training examples per category for a supervised CIFAR10 model vs. a RotNet model with the final layers fine-tuned on CIFAR10. The plot shows that pre-training on the Rotation task can be advantageous when only a small amount of labeled data is available. Using your RotNet fine-tuning code and supervised CIFAR10 training code from the main assignment, try to create a similar plot by performing supervised fine-tuning/training on only a subset of CIFAR10.
# - Use a more advanced model than ResNet18 to try to get higher accuracy on the rotation prediction task, as well as for transfer to supervised CIFAR10 classification.
#
# - If you have a good amount of compute at your disposal, try to train a rotation prediction model on the larger ImageNette dataset (still smaller than ImageNet, though).
